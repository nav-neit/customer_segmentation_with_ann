# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %% [markdown]
# ### Importing the dataset

# %%
df = pd.read_csv('Churn_Modelling.csv')
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
df.info() # there are no missing values in any column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Preprocessing the data

# %%
X = df.loc[:,['CreditScore','Geography','Gender','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary']]
X.head(5)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y = df.loc[:,'Exited']
y.head(5)
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %% [markdown]
# #### Encoding the categorical data

# %%
# we are performing OneHot encoding on the categorical variables
from sklearn.preprocessing import OneHotEncoder
oh_ec = OneHotEncoder(sparse=False,drop="first")

# %%
encoded_arr = oh_ec.fit_transform(X.loc[:,['Geography','Gender']])
cat_df = pd.DataFrame(encoded_arr,columns=['Spain','Germany','Male'])

# %%
X = X.drop(columns = ['Geography','Gender'])
X.head(5)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary
# 0               1        101348.88
# 1               1        112542.58
# 2               0        113931.57
# 3               0         93826.63
# 4               1         79084.10

# %%
X = pd.concat([X,cat_df],axis=1)
X.head(5)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Spain  Germany  Male
# 0               1        101348.88    0.0      0.0   0.0
# 1               1        112542.58    0.0      1.0   0.0
# 2               0        113931.57    0.0      0.0   0.0
# 3               0         93826.63    0.0      0.0   0.0
# 4               1         79084.10    0.0      1.0   0.0

# %% [markdown]
# ### Splitting the dataset into training set and test set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train_scaled = sc.transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
y_train_vals = y_train.iloc[:].values
y_test_vals = y_test.iloc[:].values

# %% [markdown]
# ### Building ANN using tensorflow

# %%
ann = tf.keras.models.Sequential()

# %% [markdown]
# #### adding hidden layers

# %%
# we dont need to add input layer , it will be initialized automatically
# adding first hidden layer of 6 neurons
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))
# adding a second hidden layer of 6 neurons
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %% [markdown]
# #### adding output layer

# %%
ann.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))
